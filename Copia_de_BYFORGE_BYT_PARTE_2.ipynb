# %% [markdown]
# <a href="https://colab.research.google.com/github/YorladysArgumedo06/entrega-2/blob/main/Copia_de_BYFORGE_BYT_PARTE_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *Asignacion de estudiantes en base a la malla curricular*

# %%
import pandas as pd
import random
import os
import datetime
import logging
import platform

def log_event(message):
    # Reemplazamos la funcionalidad de log_event con print para pruebas
    print(message)

# Encabezado del log con información del sistema y usuario
#user_name = os.getlogin()
system_info = platform.uname()
#print(f"Usuario: {user_name}")
print(f"Sistema: {system_info.system}")
print(f"Nodo: {system_info.node}")
print(f"Release: {system_info.release}")
print(f"Versión: {system_info.version}")
print(f"Máquina: {system_info.machine}")
print(f"Procesador: {system_info.processor}")
print(f"_____________________________________________________________________________________")
# Función para leer nombres y apellidos de los archivos proporcionados
def read_names(file):
    return pd.read_csv(file, header=None, skiprows=1, encoding='utf-8').squeeze().tolist()

# Generación de datos únicos para los estudiantes
def generate_students(num_students, first_names, last_names):
    students = []
    unique_names = set()
    while len(students) < num_students:
        full_name = f"{random.choice(first_names)} {random.choice(last_names)}"
        if full_name not in unique_names:
            unique_names.add(full_name)
            students.append({'Nombre Completo': full_name})
    return students

# Distribución de estudiantes entre los semestres
def distribute_students(students):
    distribution = [0.14, 0.13, 0.12, 0.11, 0.10, 0.10, 0.09, 0.08, 0.07, 0.06]
    semester_counts = [int(len(students) * p) for p in distribution]
    semesters = []
    for i, count in enumerate(semester_counts):
        semesters.extend([i + 1] * count)
    random.shuffle(semesters)
    for student, semester in zip(students, semesters):
        student['Semestre'] = semester
    return students

# Función para obtener las iniciales del curso
def obtener_iniciales(nombre):
    palabras_comunes = {"DE", "LA", "DEL", "Y", "EL", "LOS", "LAS"}
    palabras = nombre.split()
    iniciales = [palabra[:3] for palabra in palabras if palabra.upper() not in palabras_comunes]
    return "".join(iniciales).upper()[:3]

# Función para calcular HTD y HTI basadas en los créditos
def calcular_horas(creditos):
    if creditos == 4:
        return 96, 120
    if creditos == 3:
        return 64, 80
    if creditos == 2:
        return 32, 64
    if creditos == 1:
        return 16, 32
    return 0, 0

# Generar el código único para cada materia
def generar_codigo(nombre, nivel, creditos, consecutivo):
    iniciales = obtener_iniciales(nombre)
    return f"{iniciales}{nivel}{creditos}{consecutivo}"

# Crear archivos de cursos
def create_course_files(students, courses, folder_path):
    start_time = datetime.datetime.now()
    log_event("Inicio de la creación de archivos de cursos")

    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
    grouped = {course: [] for course in courses}

    for student in students:
        for course, info in courses.items():
            if student['Semestre'] in info['Semestres']:
                grouped[course].append(student)

    for course, data in grouped.items():
        course_path = os.path.join(folder_path, f"Semestre {courses[course]['Semestres'][0]}", course)
        if not os.path.exists(course_path):
            os.makedirs(course_path)
        num_groups = len(data) // courses[course]['Cupo'] + (1 if len(data) % courses[course]['Cupo'] else 0)
        for i in range(num_groups):
            group_data = data[i * courses[course]['Cupo']:(i + 1) * courses[course]['Cupo']]
            if group_data:
                df = pd.DataFrame(group_data)[['Nombre Completo']]
                code = course
                course_name = courses[course]['Nombre'].replace(" ", "").capitalize()
                student_count = len(group_data)
                group_code = i + 1
                filename = f"{code}-{course_name}-{student_count}-{group_code}"
                filepath_csv = os.path.join(course_path, f"{filename}.csv")
                filepath_excel = os.path.join(course_path, f"{filename}.xlsx")
              # Crear archivo CSV
                csv_start_time = datetime.datetime.now()
                df.to_csv(filepath_csv, index=False, encoding='utf-8-sig')
                csv_end_time = datetime.datetime.now()
                csv_time_taken = csv_end_time - csv_start_time
                log_event(f'Creado archivo CSV: {filepath_csv}. Tiempo: {csv_time_taken}')

                # Crear archivo Excel
                excel_start_time = datetime.datetime.now()
                df.to_excel(filepath_excel, index=False)
                excel_end_time = datetime.datetime.now()
                excel_time_taken = excel_end_time - excel_start_time
                log_event(f'Creado archivo Excel: {filepath_excel}. Tiempo: {excel_time_taken}')

    end_time = datetime.datetime.now()
    total_time_taken = end_time - start_time
    log_event(f"Fin de la creación de archivos de cursos. Tiempo total: {total_time_taken}")


# Lista de materias con información
materias = [
    {"nivel": 1, "nombre": "INGLÉS I", "creditos": 1},
    {"nivel": 1, "nombre": "INTRODUCCIÓN A LA INGENIERÍA INDUSTRIAL", "creditos": 1},
    {"nivel": 1, "nombre": "ÁLGEBRA Y TRIGONOMETRÍA", "creditos": 3},
    {"nivel": 1, "nombre": "GEOMETRÍA VECTORIAL Y ANALÍTICA", "creditos": 3},
    {"nivel": 1, "nombre": "CÁLCULO DIFERENCIAL", "creditos": 3},
    {"nivel": 1, "nombre": "LECTOESCRITURA", "creditos": 3},
    {"nivel": 1, "nombre": "VIVAMOS LA UNIVERSIDAD", "creditos": 1},
    {"nivel": 2, "nombre": "INGLÉS II", "creditos": 1},
    {"nivel": 2, "nombre": "GESTIÓN DE LAS ORGANIZACIONES", "creditos": 3},
    {"nivel": 2, "nombre": "HABILIDADES GERENCIALES", "creditos": 3},
    {"nivel": 2, "nombre": "ÁLGEBRA LINEAL", "creditos": 3},
    {"nivel": 2, "nombre": "CÁLCULO INTEGRAL", "creditos": 3},
    {"nivel": 2, "nombre": "DESCUBRIENDO LA FÍSICA", "creditos": 3},
    {"nivel": 3, "nombre": "INGLÉS III", "creditos": 1},
    {"nivel": 3, "nombre": "GESTIÓN CONTABLE", "creditos": 3},
    {"nivel": 3, "nombre": "TEORÍA GENERAL DE SISTEMAS", "creditos": 3},
    {"nivel": 3, "nombre": "PROBABILIDAD E INFERENCIA ESTADÍSTICA", "creditos": 3},
    {"nivel": 3, "nombre": "ALGORITMIA Y PROGRAMACIÓN", "creditos": 3},
    {"nivel": 3, "nombre": "FÍSICA MECÁNICA", "creditos": 3},
    {"nivel": 4, "nombre": "INGLÉS IV", "creditos": 1},
    {"nivel": 4, "nombre": "GESTIÓN DE MÉTODOS Y TIEMPOS", "creditos": 4},
    {"nivel": 4, "nombre": "INGENIERÍA ECONÓMICA", "creditos": 3},
    {"nivel": 4, "nombre": "DISEÑO DE EXPERIMENTOS Y ANÁLISIS DE REGRESIÓN", "creditos": 3},
    {"nivel": 4, "nombre": "OPTIMIZACIÓN", "creditos": 3},
    {"nivel": 5, "nombre": "INGLÉS V", "creditos": 1},
    {"nivel": 5, "nombre": "DINÁMICA DE SISTEMAS", "creditos": 3},
    {"nivel": 5, "nombre": "GESTIÓN POR PROCESOS", "creditos": 3},
    {"nivel": 5, "nombre": "GESTIÓN FINANCIERA", "creditos": 3},
    {"nivel": 5, "nombre": "MUESTREO Y SERIES DE TIEMPO", "creditos": 3},
    {"nivel": 5, "nombre": "PROCESOS ESTOCÁSTICOS Y ANÁLISIS DE DECISIÓN", "creditos": 3},
    {"nivel": 6, "nombre": "INGLÉS VI", "creditos": 1},
    {"nivel": 6, "nombre": "GESTIÓN TECNOLÓGICA", "creditos": 3},
    {"nivel": 6, "nombre": "NORMALIZACIÓN Y CONTROL DE CALIDAD", "creditos": 3},
    {"nivel": 6, "nombre": "SIMULACIÓN", "creditos": 3},
    {"nivel": 6, "nombre": "SEGURIDAD Y SALUD EN EL TRABAJO", "creditos": 3},
    {"nivel": 7, "nombre": "GESTIÓN AMBIENTAL", "creditos": 3},
    {"nivel": 7, "nombre": "FORMULACIÓN Y EVALUACIÓN DE PROYECTOS", "creditos": 3},
    {"nivel": 7, "nombre": "GESTIÓN LOGÍSTICA Y DE LA CADENA DE SUMINISTRO", "creditos": 3},
    {"nivel": 7, "nombre": "MODELACIÓN DE SISTEMAS Y SIMULACIÓN DE PROCESOS", "creditos": 3},
    {"nivel": 8, "nombre": "GESTIÓN DEL TALENTO HUMANO", "creditos": 3},
    {"nivel": 8, "nombre": "GESTIÓN DE SERVICIOS", "creditos": 3},
    {"nivel": 8, "nombre": "PLANIFICACIÓN Y CONTROL DE LA PRODUCCIÓN", "creditos": 3},
    {"nivel": 8, "nombre": "PLANEACIÓN ESTRATÉGICA", "creditos": 3},
    {"nivel": 9, "nombre": "INVESTIGACIÓN DE MERCADOS Y ANÁLISIS DE LA COMPETENCIA", "creditos": 3},
    {"nivel": 9, "nombre": "PRÁCTICAS PROFESIONALES", "creditos": 3},
]

# Cursos y su configuración
courses = {}
consecutivo = 1
for materia in materias:
    codigo = generar_codigo(materia['nombre'], materia['nivel'], materia['creditos'], consecutivo)
    courses[codigo] = {
        'Semestres': [materia['nivel']],
        'Cupo': 30 if materia['nivel'] < 4 else 25 if materia['nivel'] < 7 else 20,
        'HTD': calcular_horas(materia['creditos'])[0],
        'HTI': calcular_horas(materia['creditos'])[1],
        'Nombre': materia['nombre']
    }
    consecutivo += 1

# Archivos de nombres y apellidos
first_names = read_names('https://raw.githubusercontent.com/YorladysArgumedo06/byte-forge-parte-2-/339cb25ae56f9824da41d226d86cbdb59a9abb5d/nombres.csv')
last_names = read_names('https://raw.githubusercontent.com/YorladysArgumedo06/byte-forge-parte-2-/339cb25ae56f9824da41d226d86cbdb59a9abb5d/apellidos.csv')

# Generar y distribuir estudiantes
students = generate_students(1000, first_names, last_names)
students = distribute_students(students)

# Crear archivos de cursos
create_course_files(students, courses, 'Ruta Trabajo Final')

# Finalizar el log de eventos con un resumen
total_files = sum([len(files) for r, d, files in os.walk('Ruta Trabajo Final')])
print(f"Total de archivos creados: {total_files}")
print(f"Total de acciones realizadas: {total_files * 2}")  # Cada archivo implica crear CSV y Excel, así que se multiplica por 2
# Out:
# Sistema: Linux
# Nodo: 2eb32de64763
# Release: 6.1.85+
# Versión: #1 SMP PREEMPT_DYNAMIC Sun Apr 28 14:29:16 UTC 2024
# Máquina: x86_64
# Procesador: x86_64
# _____________________________________________________________________________________
# Inicio de la creación de archivos de cursos
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/ING111/ING111-Inglési-30-1.csv. Tiempo: 0:00:00.037665
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/ING111/ING111-Inglési-30-1.xlsx. Tiempo: 0:00:00.388526
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/ING111/ING111-Inglési-30-2.csv. Tiempo: 0:00:00.002268
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/ING111/ING111-Inglési-30-2.xlsx. Tiempo: 0:00:00.013103
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/ING111/ING111-Inglési-30-3.csv. Tiempo: 0:00:00.002039
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/ING111/ING111-Inglési-30-3.xlsx. Tiempo: 0:00:00.010910
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/ING111/ING111-Inglési-30-4.csv. Tiempo: 0:00:00.001644
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/ING111/ING111-Inglési-30-4.xlsx. Tiempo: 0:00:00.011888
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/ING111/ING111-Inglési-20-5.csv. Tiempo: 0:00:00.001877
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/ING111/ING111-Inglési-20-5.xlsx. Tiempo: 0:00:00.010431
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/INT112/INT112-Introducciónalaingenieríaindustrial-30-1.csv. Tiempo: 0:00:00.000991
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/INT112/INT112-Introducciónalaingenieríaindustrial-30-1.xlsx. Tiempo: 0:00:00.010247
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/INT112/INT112-Introducciónalaingenieríaindustrial-30-2.csv. Tiempo: 0:00:00.001675
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/INT112/INT112-Introducciónalaingenieríaindustrial-30-2.xlsx. Tiempo: 0:00:00.013554
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/INT112/INT112-Introducciónalaingenieríaindustrial-30-3.csv. Tiempo: 0:00:00.001129
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/INT112/INT112-Introducciónalaingenieríaindustrial-30-3.xlsx. Tiempo: 0:00:00.013358
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/INT112/INT112-Introducciónalaingenieríaindustrial-30-4.csv. Tiempo: 0:00:00.001526
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/INT112/INT112-Introducciónalaingenieríaindustrial-30-4.xlsx. Tiempo: 0:00:00.011117
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/INT112/INT112-Introducciónalaingenieríaindustrial-20-5.csv. Tiempo: 0:00:00.002338
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/INT112/INT112-Introducciónalaingenieríaindustrial-20-5.xlsx. Tiempo: 0:00:00.012597
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/ÁLG133/ÁLG133-Álgebraytrigonometría-30-1.csv. Tiempo: 0:00:00.001205
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/ÁLG133/ÁLG133-Álgebraytrigonometría-30-1.xlsx. Tiempo: 0:00:00.010474
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/ÁLG133/ÁLG133-Álgebraytrigonometría-30-2.csv. Tiempo: 0:00:00.002006
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/ÁLG133/ÁLG133-Álgebraytrigonometría-30-2.xlsx. Tiempo: 0:00:00.011064
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/ÁLG133/ÁLG133-Álgebraytrigonometría-30-3.csv. Tiempo: 0:00:00.001671
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/ÁLG133/ÁLG133-Álgebraytrigonometría-30-3.xlsx. Tiempo: 0:00:00.010574
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/ÁLG133/ÁLG133-Álgebraytrigonometría-30-4.csv. Tiempo: 0:00:00.001660
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/ÁLG133/ÁLG133-Álgebraytrigonometría-30-4.xlsx. Tiempo: 0:00:00.010676
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/ÁLG133/ÁLG133-Álgebraytrigonometría-20-5.csv. Tiempo: 0:00:00.004399
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/ÁLG133/ÁLG133-Álgebraytrigonometría-20-5.xlsx. Tiempo: 0:00:00.013009
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/GEO134/GEO134-Geometríavectorialyanalítica-30-1.csv. Tiempo: 0:00:00.000987
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/GEO134/GEO134-Geometríavectorialyanalítica-30-1.xlsx. Tiempo: 0:00:00.010775
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/GEO134/GEO134-Geometríavectorialyanalítica-30-2.csv. Tiempo: 0:00:00.001685
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/GEO134/GEO134-Geometríavectorialyanalítica-30-2.xlsx. Tiempo: 0:00:00.011177
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/GEO134/GEO134-Geometríavectorialyanalítica-30-3.csv. Tiempo: 0:00:00.001704
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/GEO134/GEO134-Geometríavectorialyanalítica-30-3.xlsx. Tiempo: 0:00:00.012372
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/GEO134/GEO134-Geometríavectorialyanalítica-30-4.csv. Tiempo: 0:00:00.001706
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/GEO134/GEO134-Geometríavectorialyanalítica-30-4.xlsx. Tiempo: 0:00:00.010432
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/GEO134/GEO134-Geometríavectorialyanalítica-20-5.csv. Tiempo: 0:00:00.001661
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/GEO134/GEO134-Geometríavectorialyanalítica-20-5.xlsx. Tiempo: 0:00:00.010507
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/CÁL135/CÁL135-Cálculodiferencial-30-1.csv. Tiempo: 0:00:00.001045
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/CÁL135/CÁL135-Cálculodiferencial-30-1.xlsx. Tiempo: 0:00:00.010128
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/CÁL135/CÁL135-Cálculodiferencial-30-2.csv. Tiempo: 0:00:00.001922
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/CÁL135/CÁL135-Cálculodiferencial-30-2.xlsx. Tiempo: 0:00:00.010653
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/CÁL135/CÁL135-Cálculodiferencial-30-3.csv. Tiempo: 0:00:00.001635
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/CÁL135/CÁL135-Cálculodiferencial-30-3.xlsx. Tiempo: 0:00:00.009851
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/CÁL135/CÁL135-Cálculodiferencial-30-4.csv. Tiempo: 0:00:00.001655
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/CÁL135/CÁL135-Cálculodiferencial-30-4.xlsx. Tiempo: 0:00:00.010376
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/CÁL135/CÁL135-Cálculodiferencial-20-5.csv. Tiempo: 0:00:00.001697
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/CÁL135/CÁL135-Cálculodiferencial-20-5.xlsx. Tiempo: 0:00:00.010895
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/LEC136/LEC136-Lectoescritura-30-1.csv. Tiempo: 0:00:00.001034
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/LEC136/LEC136-Lectoescritura-30-1.xlsx. Tiempo: 0:00:00.010945
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/LEC136/LEC136-Lectoescritura-30-2.csv. Tiempo: 0:00:00.001693
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/LEC136/LEC136-Lectoescritura-30-2.xlsx. Tiempo: 0:00:00.010141
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/LEC136/LEC136-Lectoescritura-30-3.csv. Tiempo: 0:00:00.001688
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/LEC136/LEC136-Lectoescritura-30-3.xlsx. Tiempo: 0:00:00.011368
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/LEC136/LEC136-Lectoescritura-30-4.csv. Tiempo: 0:00:00.001576
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/LEC136/LEC136-Lectoescritura-30-4.xlsx. Tiempo: 0:00:00.014715
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/LEC136/LEC136-Lectoescritura-20-5.csv. Tiempo: 0:00:00.001832
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/LEC136/LEC136-Lectoescritura-20-5.xlsx. Tiempo: 0:00:00.011521
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/VIV117/VIV117-Vivamoslauniversidad-30-1.csv. Tiempo: 0:00:00.001374
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/VIV117/VIV117-Vivamoslauniversidad-30-1.xlsx. Tiempo: 0:00:00.014403
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/VIV117/VIV117-Vivamoslauniversidad-30-2.csv. Tiempo: 0:00:00.001328
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/VIV117/VIV117-Vivamoslauniversidad-30-2.xlsx. Tiempo: 0:00:00.010584
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/VIV117/VIV117-Vivamoslauniversidad-30-3.csv. Tiempo: 0:00:00.001582
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/VIV117/VIV117-Vivamoslauniversidad-30-3.xlsx. Tiempo: 0:00:00.009937
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/VIV117/VIV117-Vivamoslauniversidad-30-4.csv. Tiempo: 0:00:00.001601
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/VIV117/VIV117-Vivamoslauniversidad-30-4.xlsx. Tiempo: 0:00:00.010389
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/VIV117/VIV117-Vivamoslauniversidad-20-5.csv. Tiempo: 0:00:00.001607
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/VIV117/VIV117-Vivamoslauniversidad-20-5.xlsx. Tiempo: 0:00:00.009554
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/ING218/ING218-Inglésii-30-1.csv. Tiempo: 0:00:00.000991
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/ING218/ING218-Inglésii-30-1.xlsx. Tiempo: 0:00:00.010073
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/ING218/ING218-Inglésii-30-2.csv. Tiempo: 0:00:00.001892
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/ING218/ING218-Inglésii-30-2.xlsx. Tiempo: 0:00:00.010531
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/ING218/ING218-Inglésii-30-3.csv. Tiempo: 0:00:00.001603
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/ING218/ING218-Inglésii-30-3.xlsx. Tiempo: 0:00:00.010222
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/ING218/ING218-Inglésii-30-4.csv. Tiempo: 0:00:00.001574
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/ING218/ING218-Inglésii-30-4.xlsx. Tiempo: 0:00:00.010658
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/ING218/ING218-Inglésii-10-5.csv. Tiempo: 0:00:00.001592
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/ING218/ING218-Inglésii-10-5.xlsx. Tiempo: 0:00:00.009656
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/GES239/GES239-Gestióndelasorganizaciones-30-1.csv. Tiempo: 0:00:00.000917
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/GES239/GES239-Gestióndelasorganizaciones-30-1.xlsx. Tiempo: 0:00:00.011059
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/GES239/GES239-Gestióndelasorganizaciones-30-2.csv. Tiempo: 0:00:00.001700
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/GES239/GES239-Gestióndelasorganizaciones-30-2.xlsx. Tiempo: 0:00:00.014637
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/GES239/GES239-Gestióndelasorganizaciones-30-3.csv. Tiempo: 0:00:00.001908
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/GES239/GES239-Gestióndelasorganizaciones-30-3.xlsx. Tiempo: 0:00:00.015814
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/GES239/GES239-Gestióndelasorganizaciones-30-4.csv. Tiempo: 0:00:00.001966
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/GES239/GES239-Gestióndelasorganizaciones-30-4.xlsx. Tiempo: 0:00:00.010704
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/GES239/GES239-Gestióndelasorganizaciones-10-5.csv. Tiempo: 0:00:00.003435
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/GES239/GES239-Gestióndelasorganizaciones-10-5.xlsx. Tiempo: 0:00:00.017872
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/HAB2310/HAB2310-Habilidadesgerenciales-30-1.csv. Tiempo: 0:00:00.001620
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/HAB2310/HAB2310-Habilidadesgerenciales-30-1.xlsx. Tiempo: 0:00:00.011129
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/HAB2310/HAB2310-Habilidadesgerenciales-30-2.csv. Tiempo: 0:00:00.001921
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/HAB2310/HAB2310-Habilidadesgerenciales-30-2.xlsx. Tiempo: 0:00:00.010955
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/HAB2310/HAB2310-Habilidadesgerenciales-30-3.csv. Tiempo: 0:00:00.001924
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/HAB2310/HAB2310-Habilidadesgerenciales-30-3.xlsx. Tiempo: 0:00:00.009876
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/HAB2310/HAB2310-Habilidadesgerenciales-30-4.csv. Tiempo: 0:00:00.001561
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/HAB2310/HAB2310-Habilidadesgerenciales-30-4.xlsx. Tiempo: 0:00:00.010027
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/HAB2310/HAB2310-Habilidadesgerenciales-10-5.csv. Tiempo: 0:00:00.001648
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/HAB2310/HAB2310-Habilidadesgerenciales-10-5.xlsx. Tiempo: 0:00:00.009484
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/ÁLG2311/ÁLG2311-Álgebralineal-30-1.csv. Tiempo: 0:00:00.001632
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/ÁLG2311/ÁLG2311-Álgebralineal-30-1.xlsx. Tiempo: 0:00:00.010964
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/ÁLG2311/ÁLG2311-Álgebralineal-30-2.csv. Tiempo: 0:00:00.001635
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/ÁLG2311/ÁLG2311-Álgebralineal-30-2.xlsx. Tiempo: 0:00:00.010261
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/ÁLG2311/ÁLG2311-Álgebralineal-30-3.csv. Tiempo: 0:00:00.001593
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/ÁLG2311/ÁLG2311-Álgebralineal-30-3.xlsx. Tiempo: 0:00:00.009916
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/ÁLG2311/ÁLG2311-Álgebralineal-30-4.csv. Tiempo: 0:00:00.001552
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/ÁLG2311/ÁLG2311-Álgebralineal-30-4.xlsx. Tiempo: 0:00:00.010775
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/ÁLG2311/ÁLG2311-Álgebralineal-10-5.csv. Tiempo: 0:00:00.001880
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/ÁLG2311/ÁLG2311-Álgebralineal-10-5.xlsx. Tiempo: 0:00:00.010085
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/CÁL2312/CÁL2312-Cálculointegral-30-1.csv. Tiempo: 0:00:00.000940
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/CÁL2312/CÁL2312-Cálculointegral-30-1.xlsx. Tiempo: 0:00:00.009939
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/CÁL2312/CÁL2312-Cálculointegral-30-2.csv. Tiempo: 0:00:00.001545
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/CÁL2312/CÁL2312-Cálculointegral-30-2.xlsx. Tiempo: 0:00:00.015547
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/CÁL2312/CÁL2312-Cálculointegral-30-3.csv. Tiempo: 0:00:00.000995
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/CÁL2312/CÁL2312-Cálculointegral-30-3.xlsx. Tiempo: 0:00:00.010230
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/CÁL2312/CÁL2312-Cálculointegral-30-4.csv. Tiempo: 0:00:00.001616
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/CÁL2312/CÁL2312-Cálculointegral-30-4.xlsx. Tiempo: 0:00:00.010740
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/CÁL2312/CÁL2312-Cálculointegral-10-5.csv. Tiempo: 0:00:00.001569
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/CÁL2312/CÁL2312-Cálculointegral-10-5.xlsx. Tiempo: 0:00:00.009316
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/DES2313/DES2313-Descubriendolafísica-30-1.csv. Tiempo: 0:00:00.000878
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/DES2313/DES2313-Descubriendolafísica-30-1.xlsx. Tiempo: 0:00:00.013052
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/DES2313/DES2313-Descubriendolafísica-30-2.csv. Tiempo: 0:00:00.001984
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/DES2313/DES2313-Descubriendolafísica-30-2.xlsx. Tiempo: 0:00:00.010394
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/DES2313/DES2313-Descubriendolafísica-30-3.csv. Tiempo: 0:00:00.002049
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/DES2313/DES2313-Descubriendolafísica-30-3.xlsx. Tiempo: 0:00:00.010056
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/DES2313/DES2313-Descubriendolafísica-30-4.csv. Tiempo: 0:00:00.001498
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/DES2313/DES2313-Descubriendolafísica-30-4.xlsx. Tiempo: 0:00:00.009763
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/DES2313/DES2313-Descubriendolafísica-10-5.csv. Tiempo: 0:00:00.001799
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/DES2313/DES2313-Descubriendolafísica-10-5.xlsx. Tiempo: 0:00:00.014234
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/ING3114/ING3114-Inglésiii-30-1.csv. Tiempo: 0:00:00.001366
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/ING3114/ING3114-Inglésiii-30-1.xlsx. Tiempo: 0:00:00.010716
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/ING3114/ING3114-Inglésiii-30-2.csv. Tiempo: 0:00:00.001619
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/ING3114/ING3114-Inglésiii-30-2.xlsx. Tiempo: 0:00:00.010563
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/ING3114/ING3114-Inglésiii-30-3.csv. Tiempo: 0:00:00.001857
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/ING3114/ING3114-Inglésiii-30-3.xlsx. Tiempo: 0:00:00.011187
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/ING3114/ING3114-Inglésiii-30-4.csv. Tiempo: 0:00:00.001675
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/ING3114/ING3114-Inglésiii-30-4.xlsx. Tiempo: 0:00:00.011745
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/GES3315/GES3315-Gestióncontable-30-1.csv. Tiempo: 0:00:00.001052
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/GES3315/GES3315-Gestióncontable-30-1.xlsx. Tiempo: 0:00:00.009927
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/GES3315/GES3315-Gestióncontable-30-2.csv. Tiempo: 0:00:00.001631
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/GES3315/GES3315-Gestióncontable-30-2.xlsx. Tiempo: 0:00:00.010332
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/GES3315/GES3315-Gestióncontable-30-3.csv. Tiempo: 0:00:00.002483
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/GES3315/GES3315-Gestióncontable-30-3.xlsx. Tiempo: 0:00:00.013313
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/GES3315/GES3315-Gestióncontable-30-4.csv. Tiempo: 0:00:00.001809
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/GES3315/GES3315-Gestióncontable-30-4.xlsx. Tiempo: 0:00:00.011035
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/TEO3316/TEO3316-Teoríageneraldesistemas-30-1.csv. Tiempo: 0:00:00.000950
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/TEO3316/TEO3316-Teoríageneraldesistemas-30-1.xlsx. Tiempo: 0:00:00.013393
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/TEO3316/TEO3316-Teoríageneraldesistemas-30-2.csv. Tiempo: 0:00:00.001829
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/TEO3316/TEO3316-Teoríageneraldesistemas-30-2.xlsx. Tiempo: 0:00:00.011944
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/TEO3316/TEO3316-Teoríageneraldesistemas-30-3.csv. Tiempo: 0:00:00.001986
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/TEO3316/TEO3316-Teoríageneraldesistemas-30-3.xlsx. Tiempo: 0:00:00.011366
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/TEO3316/TEO3316-Teoríageneraldesistemas-30-4.csv. Tiempo: 0:00:00.001725
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/TEO3316/TEO3316-Teoríageneraldesistemas-30-4.xlsx. Tiempo: 0:00:00.011055
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/PRO3317/PRO3317-Probabilidadeinferenciaestadística-30-1.csv. Tiempo: 0:00:00.001217
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/PRO3317/PRO3317-Probabilidadeinferenciaestadística-30-1.xlsx. Tiempo: 0:00:00.010237
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/PRO3317/PRO3317-Probabilidadeinferenciaestadística-30-2.csv. Tiempo: 0:00:00.001630
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/PRO3317/PRO3317-Probabilidadeinferenciaestadística-30-2.xlsx. Tiempo: 0:00:00.010286
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/PRO3317/PRO3317-Probabilidadeinferenciaestadística-30-3.csv. Tiempo: 0:00:00.001592
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/PRO3317/PRO3317-Probabilidadeinferenciaestadística-30-3.xlsx. Tiempo: 0:00:00.010074
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/PRO3317/PRO3317-Probabilidadeinferenciaestadística-30-4.csv. Tiempo: 0:00:00.001774
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/PRO3317/PRO3317-Probabilidadeinferenciaestadística-30-4.xlsx. Tiempo: 0:00:00.009736
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/ALG3318/ALG3318-Algoritmiayprogramación-30-1.csv. Tiempo: 0:00:00.000898
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/ALG3318/ALG3318-Algoritmiayprogramación-30-1.xlsx. Tiempo: 0:00:00.011524
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/ALG3318/ALG3318-Algoritmiayprogramación-30-2.csv. Tiempo: 0:00:00.001287
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/ALG3318/ALG3318-Algoritmiayprogramación-30-2.xlsx. Tiempo: 0:00:00.010677
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/ALG3318/ALG3318-Algoritmiayprogramación-30-3.csv. Tiempo: 0:00:00.001592
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/ALG3318/ALG3318-Algoritmiayprogramación-30-3.xlsx. Tiempo: 0:00:00.010994
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/ALG3318/ALG3318-Algoritmiayprogramación-30-4.csv. Tiempo: 0:00:00.001716
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/ALG3318/ALG3318-Algoritmiayprogramación-30-4.xlsx. Tiempo: 0:00:00.011558
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/FÍS3319/FÍS3319-Físicamecánica-30-1.csv. Tiempo: 0:00:00.000953
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/FÍS3319/FÍS3319-Físicamecánica-30-1.xlsx. Tiempo: 0:00:00.016022
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/FÍS3319/FÍS3319-Físicamecánica-30-2.csv. Tiempo: 0:00:00.002103
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/FÍS3319/FÍS3319-Físicamecánica-30-2.xlsx. Tiempo: 0:00:00.010219
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/FÍS3319/FÍS3319-Físicamecánica-30-3.csv. Tiempo: 0:00:00.001525
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/FÍS3319/FÍS3319-Físicamecánica-30-3.xlsx. Tiempo: 0:00:00.010179
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/FÍS3319/FÍS3319-Físicamecánica-30-4.csv. Tiempo: 0:00:00.001660
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/FÍS3319/FÍS3319-Físicamecánica-30-4.xlsx. Tiempo: 0:00:00.010134
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/ING4120/ING4120-Inglésiv-25-1.csv. Tiempo: 0:00:00.000912
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/ING4120/ING4120-Inglésiv-25-1.xlsx. Tiempo: 0:00:00.009724
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/ING4120/ING4120-Inglésiv-25-2.csv. Tiempo: 0:00:00.001617
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/ING4120/ING4120-Inglésiv-25-2.xlsx. Tiempo: 0:00:00.009659
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/ING4120/ING4120-Inglésiv-25-3.csv. Tiempo: 0:00:00.001620
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/ING4120/ING4120-Inglésiv-25-3.xlsx. Tiempo: 0:00:00.009797
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/ING4120/ING4120-Inglésiv-25-4.csv. Tiempo: 0:00:00.001598
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/ING4120/ING4120-Inglésiv-25-4.xlsx. Tiempo: 0:00:00.009978
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/ING4120/ING4120-Inglésiv-10-5.csv. Tiempo: 0:00:00.001528
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/ING4120/ING4120-Inglésiv-10-5.xlsx. Tiempo: 0:00:00.010292
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/GES4421/GES4421-Gestióndemétodosytiempos-25-1.csv. Tiempo: 0:00:00.001742
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/GES4421/GES4421-Gestióndemétodosytiempos-25-1.xlsx. Tiempo: 0:00:00.011447
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/GES4421/GES4421-Gestióndemétodosytiempos-25-2.csv. Tiempo: 0:00:00.001642
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/GES4421/GES4421-Gestióndemétodosytiempos-25-2.xlsx. Tiempo: 0:00:00.010327
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/GES4421/GES4421-Gestióndemétodosytiempos-25-3.csv. Tiempo: 0:00:00.001639
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/GES4421/GES4421-Gestióndemétodosytiempos-25-3.xlsx. Tiempo: 0:00:00.011030
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/GES4421/GES4421-Gestióndemétodosytiempos-25-4.csv. Tiempo: 0:00:00.002321
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/GES4421/GES4421-Gestióndemétodosytiempos-25-4.xlsx. Tiempo: 0:00:00.011379
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/GES4421/GES4421-Gestióndemétodosytiempos-10-5.csv. Tiempo: 0:00:00.002221
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/GES4421/GES4421-Gestióndemétodosytiempos-10-5.xlsx. Tiempo: 0:00:00.013125
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/ING4322/ING4322-Ingenieríaeconómica-25-1.csv. Tiempo: 0:00:00.001474
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/ING4322/ING4322-Ingenieríaeconómica-25-1.xlsx. Tiempo: 0:00:00.027451
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/ING4322/ING4322-Ingenieríaeconómica-25-2.csv. Tiempo: 0:00:00.003681
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/ING4322/ING4322-Ingenieríaeconómica-25-2.xlsx. Tiempo: 0:00:00.011868
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/ING4322/ING4322-Ingenieríaeconómica-25-3.csv. Tiempo: 0:00:00.001903
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/ING4322/ING4322-Ingenieríaeconómica-25-3.xlsx. Tiempo: 0:00:00.011298
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/ING4322/ING4322-Ingenieríaeconómica-25-4.csv. Tiempo: 0:00:00.001927
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/ING4322/ING4322-Ingenieríaeconómica-25-4.xlsx. Tiempo: 0:00:00.011014
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/ING4322/ING4322-Ingenieríaeconómica-10-5.csv. Tiempo: 0:00:00.001785
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/ING4322/ING4322-Ingenieríaeconómica-10-5.xlsx. Tiempo: 0:00:00.010358
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/DIS4323/DIS4323-Diseñodeexperimentosyanálisisderegresión-25-1.csv. Tiempo: 0:00:00.001360
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/DIS4323/DIS4323-Diseñodeexperimentosyanálisisderegresión-25-1.xlsx. Tiempo: 0:00:00.013257
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/DIS4323/DIS4323-Diseñodeexperimentosyanálisisderegresión-25-2.csv. Tiempo: 0:00:00.001968
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/DIS4323/DIS4323-Diseñodeexperimentosyanálisisderegresión-25-2.xlsx. Tiempo: 0:00:00.011919
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/DIS4323/DIS4323-Diseñodeexperimentosyanálisisderegresión-25-3.csv. Tiempo: 0:00:00.002326
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/DIS4323/DIS4323-Diseñodeexperimentosyanálisisderegresión-25-3.xlsx. Tiempo: 0:00:00.012069
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/DIS4323/DIS4323-Diseñodeexperimentosyanálisisderegresión-25-4.csv. Tiempo: 0:00:00.001897
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/DIS4323/DIS4323-Diseñodeexperimentosyanálisisderegresión-25-4.xlsx. Tiempo: 0:00:00.010442
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/DIS4323/DIS4323-Diseñodeexperimentosyanálisisderegresión-10-5.csv. Tiempo: 0:00:00.001744
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/DIS4323/DIS4323-Diseñodeexperimentosyanálisisderegresión-10-5.xlsx. Tiempo: 0:00:00.010380
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/OPT4324/OPT4324-Optimización-25-1.csv. Tiempo: 0:00:00.001321
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/OPT4324/OPT4324-Optimización-25-1.xlsx. Tiempo: 0:00:00.011986
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/OPT4324/OPT4324-Optimización-25-2.csv. Tiempo: 0:00:00.002142
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/OPT4324/OPT4324-Optimización-25-2.xlsx. Tiempo: 0:00:00.012441
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/OPT4324/OPT4324-Optimización-25-3.csv. Tiempo: 0:00:00.002075
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/OPT4324/OPT4324-Optimización-25-3.xlsx. Tiempo: 0:00:00.012726
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/OPT4324/OPT4324-Optimización-25-4.csv. Tiempo: 0:00:00.002401
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/OPT4324/OPT4324-Optimización-25-4.xlsx. Tiempo: 0:00:00.016593
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/OPT4324/OPT4324-Optimización-10-5.csv. Tiempo: 0:00:00.001105
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/OPT4324/OPT4324-Optimización-10-5.xlsx. Tiempo: 0:00:00.010527
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/ING5125/ING5125-Inglésv-25-1.csv. Tiempo: 0:00:00.001071
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/ING5125/ING5125-Inglésv-25-1.xlsx. Tiempo: 0:00:00.012230
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/ING5125/ING5125-Inglésv-25-2.csv. Tiempo: 0:00:00.002029
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/ING5125/ING5125-Inglésv-25-2.xlsx. Tiempo: 0:00:00.012429
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/ING5125/ING5125-Inglésv-25-3.csv. Tiempo: 0:00:00.001935
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/ING5125/ING5125-Inglésv-25-3.xlsx. Tiempo: 0:00:00.011558
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/ING5125/ING5125-Inglésv-25-4.csv. Tiempo: 0:00:00.001949
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/ING5125/ING5125-Inglésv-25-4.xlsx. Tiempo: 0:00:00.010787
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/DIN5326/DIN5326-Dinámicadesistemas-25-1.csv. Tiempo: 0:00:00.001077
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/DIN5326/DIN5326-Dinámicadesistemas-25-1.xlsx. Tiempo: 0:00:00.011761
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/DIN5326/DIN5326-Dinámicadesistemas-25-2.csv. Tiempo: 0:00:00.002380
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/DIN5326/DIN5326-Dinámicadesistemas-25-2.xlsx. Tiempo: 0:00:00.019431
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/DIN5326/DIN5326-Dinámicadesistemas-25-3.csv. Tiempo: 0:00:00.002046
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/DIN5326/DIN5326-Dinámicadesistemas-25-3.xlsx. Tiempo: 0:00:00.014665
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/DIN5326/DIN5326-Dinámicadesistemas-25-4.csv. Tiempo: 0:00:00.002078
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/DIN5326/DIN5326-Dinámicadesistemas-25-4.xlsx. Tiempo: 0:00:00.011522
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/GES5327/GES5327-Gestiónporprocesos-25-1.csv. Tiempo: 0:00:00.001150
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/GES5327/GES5327-Gestiónporprocesos-25-1.xlsx. Tiempo: 0:00:00.012768
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/GES5327/GES5327-Gestiónporprocesos-25-2.csv. Tiempo: 0:00:00.002118
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/GES5327/GES5327-Gestiónporprocesos-25-2.xlsx. Tiempo: 0:00:00.011406
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/GES5327/GES5327-Gestiónporprocesos-25-3.csv. Tiempo: 0:00:00.002354
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/GES5327/GES5327-Gestiónporprocesos-25-3.xlsx. Tiempo: 0:00:00.013840
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/GES5327/GES5327-Gestiónporprocesos-25-4.csv. Tiempo: 0:00:00.005051
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/GES5327/GES5327-Gestiónporprocesos-25-4.xlsx. Tiempo: 0:00:00.011371
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/GES5328/GES5328-Gestiónfinanciera-25-1.csv. Tiempo: 0:00:00.001243
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/GES5328/GES5328-Gestiónfinanciera-25-1.xlsx. Tiempo: 0:00:00.011148
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/GES5328/GES5328-Gestiónfinanciera-25-2.csv. Tiempo: 0:00:00.001986
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/GES5328/GES5328-Gestiónfinanciera-25-2.xlsx. Tiempo: 0:00:00.011888
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/GES5328/GES5328-Gestiónfinanciera-25-3.csv. Tiempo: 0:00:00.001948
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/GES5328/GES5328-Gestiónfinanciera-25-3.xlsx. Tiempo: 0:00:00.011923
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/GES5328/GES5328-Gestiónfinanciera-25-4.csv. Tiempo: 0:00:00.001899
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/GES5328/GES5328-Gestiónfinanciera-25-4.xlsx. Tiempo: 0:00:00.010819
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/MUE5329/MUE5329-Muestreoyseriesdetiempo-25-1.csv. Tiempo: 0:00:00.001563
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/MUE5329/MUE5329-Muestreoyseriesdetiempo-25-1.xlsx. Tiempo: 0:00:00.014524
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/MUE5329/MUE5329-Muestreoyseriesdetiempo-25-2.csv. Tiempo: 0:00:00.002056
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/MUE5329/MUE5329-Muestreoyseriesdetiempo-25-2.xlsx. Tiempo: 0:00:00.011414
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/MUE5329/MUE5329-Muestreoyseriesdetiempo-25-3.csv. Tiempo: 0:00:00.002191
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/MUE5329/MUE5329-Muestreoyseriesdetiempo-25-3.xlsx. Tiempo: 0:00:00.011489
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/MUE5329/MUE5329-Muestreoyseriesdetiempo-25-4.csv. Tiempo: 0:00:00.001984
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/MUE5329/MUE5329-Muestreoyseriesdetiempo-25-4.xlsx. Tiempo: 0:00:00.012131
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/PRO5330/PRO5330-Procesosestocásticosyanálisisdedecisión-25-1.csv. Tiempo: 0:00:00.001267
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/PRO5330/PRO5330-Procesosestocásticosyanálisisdedecisión-25-1.xlsx. Tiempo: 0:00:00.011239
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/PRO5330/PRO5330-Procesosestocásticosyanálisisdedecisión-25-2.csv. Tiempo: 0:00:00.002015
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/PRO5330/PRO5330-Procesosestocásticosyanálisisdedecisión-25-2.xlsx. Tiempo: 0:00:00.013575
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/PRO5330/PRO5330-Procesosestocásticosyanálisisdedecisión-25-3.csv. Tiempo: 0:00:00.001915
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/PRO5330/PRO5330-Procesosestocásticosyanálisisdedecisión-25-3.xlsx. Tiempo: 0:00:00.011599
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/PRO5330/PRO5330-Procesosestocásticosyanálisisdedecisión-25-4.csv. Tiempo: 0:00:00.002013
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/PRO5330/PRO5330-Procesosestocásticosyanálisisdedecisión-25-4.xlsx. Tiempo: 0:00:00.016121
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/ING6131/ING6131-Inglésvi-25-1.csv. Tiempo: 0:00:00.001275
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/ING6131/ING6131-Inglésvi-25-1.xlsx. Tiempo: 0:00:00.012125
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/ING6131/ING6131-Inglésvi-25-2.csv. Tiempo: 0:00:00.002247
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/ING6131/ING6131-Inglésvi-25-2.xlsx. Tiempo: 0:00:00.011513
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/ING6131/ING6131-Inglésvi-25-3.csv. Tiempo: 0:00:00.001890
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/ING6131/ING6131-Inglésvi-25-3.xlsx. Tiempo: 0:00:00.012126
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/ING6131/ING6131-Inglésvi-25-4.csv. Tiempo: 0:00:00.001870
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/ING6131/ING6131-Inglésvi-25-4.xlsx. Tiempo: 0:00:00.010643
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/GES6332/GES6332-Gestióntecnológica-25-1.csv. Tiempo: 0:00:00.001398
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/GES6332/GES6332-Gestióntecnológica-25-1.xlsx. Tiempo: 0:00:00.012010
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/GES6332/GES6332-Gestióntecnológica-25-2.csv. Tiempo: 0:00:00.002010
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/GES6332/GES6332-Gestióntecnológica-25-2.xlsx. Tiempo: 0:00:00.011644
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/GES6332/GES6332-Gestióntecnológica-25-3.csv. Tiempo: 0:00:00.001960
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/GES6332/GES6332-Gestióntecnológica-25-3.xlsx. Tiempo: 0:00:00.012586
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/GES6332/GES6332-Gestióntecnológica-25-4.csv. Tiempo: 0:00:00.001994
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/GES6332/GES6332-Gestióntecnológica-25-4.xlsx. Tiempo: 0:00:00.011778
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/NOR6333/NOR6333-Normalizaciónycontroldecalidad-25-1.csv. Tiempo: 0:00:00.001103
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/NOR6333/NOR6333-Normalizaciónycontroldecalidad-25-1.xlsx. Tiempo: 0:00:00.011955
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/NOR6333/NOR6333-Normalizaciónycontroldecalidad-25-2.csv. Tiempo: 0:00:00.001892
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/NOR6333/NOR6333-Normalizaciónycontroldecalidad-25-2.xlsx. Tiempo: 0:00:00.011032
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/NOR6333/NOR6333-Normalizaciónycontroldecalidad-25-3.csv. Tiempo: 0:00:00.001846
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/NOR6333/NOR6333-Normalizaciónycontroldecalidad-25-3.xlsx. Tiempo: 0:00:00.010877
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/NOR6333/NOR6333-Normalizaciónycontroldecalidad-25-4.csv. Tiempo: 0:00:00.001897
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/NOR6333/NOR6333-Normalizaciónycontroldecalidad-25-4.xlsx. Tiempo: 0:00:00.010965
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/SIM6334/SIM6334-Simulación-25-1.csv. Tiempo: 0:00:00.001182
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/SIM6334/SIM6334-Simulación-25-1.xlsx. Tiempo: 0:00:00.016746
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/SIM6334/SIM6334-Simulación-25-2.csv. Tiempo: 0:00:00.002238
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/SIM6334/SIM6334-Simulación-25-2.xlsx. Tiempo: 0:00:00.011288
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/SIM6334/SIM6334-Simulación-25-3.csv. Tiempo: 0:00:00.001901
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/SIM6334/SIM6334-Simulación-25-3.xlsx. Tiempo: 0:00:00.012498
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/SIM6334/SIM6334-Simulación-25-4.csv. Tiempo: 0:00:00.001986
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/SIM6334/SIM6334-Simulación-25-4.xlsx. Tiempo: 0:00:00.012260
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/SEG6335/SEG6335-Seguridadysaludeneltrabajo-25-1.csv. Tiempo: 0:00:00.001193
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/SEG6335/SEG6335-Seguridadysaludeneltrabajo-25-1.xlsx. Tiempo: 0:00:00.011516
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/SEG6335/SEG6335-Seguridadysaludeneltrabajo-25-2.csv. Tiempo: 0:00:00.001872
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/SEG6335/SEG6335-Seguridadysaludeneltrabajo-25-2.xlsx. Tiempo: 0:00:00.011402
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/SEG6335/SEG6335-Seguridadysaludeneltrabajo-25-3.csv. Tiempo: 0:00:00.001896
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/SEG6335/SEG6335-Seguridadysaludeneltrabajo-25-3.xlsx. Tiempo: 0:00:00.014880
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/SEG6335/SEG6335-Seguridadysaludeneltrabajo-25-4.csv. Tiempo: 0:00:00.002012
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/SEG6335/SEG6335-Seguridadysaludeneltrabajo-25-4.xlsx. Tiempo: 0:00:00.012746
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/GES7336/GES7336-Gestiónambiental-20-1.csv. Tiempo: 0:00:00.001075
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/GES7336/GES7336-Gestiónambiental-20-1.xlsx. Tiempo: 0:00:00.012242
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/GES7336/GES7336-Gestiónambiental-20-2.csv. Tiempo: 0:00:00.002541
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/GES7336/GES7336-Gestiónambiental-20-2.xlsx. Tiempo: 0:00:00.012819
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/GES7336/GES7336-Gestiónambiental-20-3.csv. Tiempo: 0:00:00.000896
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/GES7336/GES7336-Gestiónambiental-20-3.xlsx. Tiempo: 0:00:00.016223
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/GES7336/GES7336-Gestiónambiental-20-4.csv. Tiempo: 0:00:00.002277
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/GES7336/GES7336-Gestiónambiental-20-4.xlsx. Tiempo: 0:00:00.012075
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/GES7336/GES7336-Gestiónambiental-10-5.csv. Tiempo: 0:00:00.001365
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/GES7336/GES7336-Gestiónambiental-10-5.xlsx. Tiempo: 0:00:00.010578
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/FOR7337/FOR7337-Formulaciónyevaluacióndeproyectos-20-1.csv. Tiempo: 0:00:00.002055
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/FOR7337/FOR7337-Formulaciónyevaluacióndeproyectos-20-1.xlsx. Tiempo: 0:00:00.010811
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/FOR7337/FOR7337-Formulaciónyevaluacióndeproyectos-20-2.csv. Tiempo: 0:00:00.001524
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/FOR7337/FOR7337-Formulaciónyevaluacióndeproyectos-20-2.xlsx. Tiempo: 0:00:00.009185
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/FOR7337/FOR7337-Formulaciónyevaluacióndeproyectos-20-3.csv. Tiempo: 0:00:00.001520
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/FOR7337/FOR7337-Formulaciónyevaluacióndeproyectos-20-3.xlsx. Tiempo: 0:00:00.009673
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/FOR7337/FOR7337-Formulaciónyevaluacióndeproyectos-20-4.csv. Tiempo: 0:00:00.001686
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/FOR7337/FOR7337-Formulaciónyevaluacióndeproyectos-20-4.xlsx. Tiempo: 0:00:00.009621
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/FOR7337/FOR7337-Formulaciónyevaluacióndeproyectos-10-5.csv. Tiempo: 0:00:00.001612
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/FOR7337/FOR7337-Formulaciónyevaluacióndeproyectos-10-5.xlsx. Tiempo: 0:00:00.009191
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/GES7338/GES7338-Gestiónlogísticaydelacadenadesuministro-20-1.csv. Tiempo: 0:00:00.000865
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/GES7338/GES7338-Gestiónlogísticaydelacadenadesuministro-20-1.xlsx. Tiempo: 0:00:00.009860
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/GES7338/GES7338-Gestiónlogísticaydelacadenadesuministro-20-2.csv. Tiempo: 0:00:00.001673
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/GES7338/GES7338-Gestiónlogísticaydelacadenadesuministro-20-2.xlsx. Tiempo: 0:00:00.009607
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/GES7338/GES7338-Gestiónlogísticaydelacadenadesuministro-20-3.csv. Tiempo: 0:00:00.001887
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/GES7338/GES7338-Gestiónlogísticaydelacadenadesuministro-20-3.xlsx. Tiempo: 0:00:00.012196
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/GES7338/GES7338-Gestiónlogísticaydelacadenadesuministro-20-4.csv. Tiempo: 0:00:00.001589
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/GES7338/GES7338-Gestiónlogísticaydelacadenadesuministro-20-4.xlsx. Tiempo: 0:00:00.010195
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/GES7338/GES7338-Gestiónlogísticaydelacadenadesuministro-10-5.csv. Tiempo: 0:00:00.001636
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/GES7338/GES7338-Gestiónlogísticaydelacadenadesuministro-10-5.xlsx. Tiempo: 0:00:00.010239
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/MOD7339/MOD7339-Modelacióndesistemasysimulacióndeprocesos-20-1.csv. Tiempo: 0:00:00.000924
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/MOD7339/MOD7339-Modelacióndesistemasysimulacióndeprocesos-20-1.xlsx. Tiempo: 0:00:00.010036
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/MOD7339/MOD7339-Modelacióndesistemasysimulacióndeprocesos-20-2.csv. Tiempo: 0:00:00.001506
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/MOD7339/MOD7339-Modelacióndesistemasysimulacióndeprocesos-20-2.xlsx. Tiempo: 0:00:00.009591
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/MOD7339/MOD7339-Modelacióndesistemasysimulacióndeprocesos-20-3.csv. Tiempo: 0:00:00.001536
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/MOD7339/MOD7339-Modelacióndesistemasysimulacióndeprocesos-20-3.xlsx. Tiempo: 0:00:00.008975
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/MOD7339/MOD7339-Modelacióndesistemasysimulacióndeprocesos-20-4.csv. Tiempo: 0:00:00.001223
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/MOD7339/MOD7339-Modelacióndesistemasysimulacióndeprocesos-20-4.xlsx. Tiempo: 0:00:00.011037
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/MOD7339/MOD7339-Modelacióndesistemasysimulacióndeprocesos-10-5.csv. Tiempo: 0:00:00.001582
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/MOD7339/MOD7339-Modelacióndesistemasysimulacióndeprocesos-10-5.xlsx. Tiempo: 0:00:00.010513
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/GES8340/GES8340-Gestióndeltalentohumano-20-1.csv. Tiempo: 0:00:00.002295
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/GES8340/GES8340-Gestióndeltalentohumano-20-1.xlsx. Tiempo: 0:00:00.012030
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/GES8340/GES8340-Gestióndeltalentohumano-20-2.csv. Tiempo: 0:00:00.001639
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/GES8340/GES8340-Gestióndeltalentohumano-20-2.xlsx. Tiempo: 0:00:00.009315
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/GES8340/GES8340-Gestióndeltalentohumano-20-3.csv. Tiempo: 0:00:00.001554
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/GES8340/GES8340-Gestióndeltalentohumano-20-3.xlsx. Tiempo: 0:00:00.010600
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/GES8340/GES8340-Gestióndeltalentohumano-20-4.csv. Tiempo: 0:00:00.001757
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/GES8340/GES8340-Gestióndeltalentohumano-20-4.xlsx. Tiempo: 0:00:00.009510
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/GES8341/GES8341-Gestióndeservicios-20-1.csv. Tiempo: 0:00:00.000871
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/GES8341/GES8341-Gestióndeservicios-20-1.xlsx. Tiempo: 0:00:00.009720
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/GES8341/GES8341-Gestióndeservicios-20-2.csv. Tiempo: 0:00:00.001515
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/GES8341/GES8341-Gestióndeservicios-20-2.xlsx. Tiempo: 0:00:00.012570
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/GES8341/GES8341-Gestióndeservicios-20-3.csv. Tiempo: 0:00:00.001577
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/GES8341/GES8341-Gestióndeservicios-20-3.xlsx. Tiempo: 0:00:00.009714
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/GES8341/GES8341-Gestióndeservicios-20-4.csv. Tiempo: 0:00:00.001543
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/GES8341/GES8341-Gestióndeservicios-20-4.xlsx. Tiempo: 0:00:00.013043
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/PLA8342/PLA8342-Planificaciónycontroldelaproducción-20-1.csv. Tiempo: 0:00:00.000900
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/PLA8342/PLA8342-Planificaciónycontroldelaproducción-20-1.xlsx. Tiempo: 0:00:00.009877
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/PLA8342/PLA8342-Planificaciónycontroldelaproducción-20-2.csv. Tiempo: 0:00:00.001528
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/PLA8342/PLA8342-Planificaciónycontroldelaproducción-20-2.xlsx. Tiempo: 0:00:00.009722
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/PLA8342/PLA8342-Planificaciónycontroldelaproducción-20-3.csv. Tiempo: 0:00:00.001752
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/PLA8342/PLA8342-Planificaciónycontroldelaproducción-20-3.xlsx. Tiempo: 0:00:00.009777
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/PLA8342/PLA8342-Planificaciónycontroldelaproducción-20-4.csv. Tiempo: 0:00:00.001539
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/PLA8342/PLA8342-Planificaciónycontroldelaproducción-20-4.xlsx. Tiempo: 0:00:00.009941
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/PLA8343/PLA8343-Planeaciónestratégica-20-1.csv. Tiempo: 0:00:00.000856
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/PLA8343/PLA8343-Planeaciónestratégica-20-1.xlsx. Tiempo: 0:00:00.010086
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/PLA8343/PLA8343-Planeaciónestratégica-20-2.csv. Tiempo: 0:00:00.001549
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/PLA8343/PLA8343-Planeaciónestratégica-20-2.xlsx. Tiempo: 0:00:00.009559
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/PLA8343/PLA8343-Planeaciónestratégica-20-3.csv. Tiempo: 0:00:00.002042
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/PLA8343/PLA8343-Planeaciónestratégica-20-3.xlsx. Tiempo: 0:00:00.015328
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/PLA8343/PLA8343-Planeaciónestratégica-20-4.csv. Tiempo: 0:00:00.001795
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/PLA8343/PLA8343-Planeaciónestratégica-20-4.xlsx. Tiempo: 0:00:00.010070
# Creado archivo CSV: Ruta Trabajo Final/Semestre 9/INV9344/INV9344-Investigacióndemercadosyanálisisdelacompetencia-20-1.csv. Tiempo: 0:00:00.000823
# Creado archivo Excel: Ruta Trabajo Final/Semestre 9/INV9344/INV9344-Investigacióndemercadosyanálisisdelacompetencia-20-1.xlsx. Tiempo: 0:00:00.010224
# Creado archivo CSV: Ruta Trabajo Final/Semestre 9/INV9344/INV9344-Investigacióndemercadosyanálisisdelacompetencia-20-2.csv. Tiempo: 0:00:00.001533
# Creado archivo Excel: Ruta Trabajo Final/Semestre 9/INV9344/INV9344-Investigacióndemercadosyanálisisdelacompetencia-20-2.xlsx. Tiempo: 0:00:00.009381
# Creado archivo CSV: Ruta Trabajo Final/Semestre 9/INV9344/INV9344-Investigacióndemercadosyanálisisdelacompetencia-20-3.csv. Tiempo: 0:00:00.001621
# Creado archivo Excel: Ruta Trabajo Final/Semestre 9/INV9344/INV9344-Investigacióndemercadosyanálisisdelacompetencia-20-3.xlsx. Tiempo: 0:00:00.009791
# Creado archivo CSV: Ruta Trabajo Final/Semestre 9/INV9344/INV9344-Investigacióndemercadosyanálisisdelacompetencia-10-4.csv. Tiempo: 0:00:00.001634
# Creado archivo Excel: Ruta Trabajo Final/Semestre 9/INV9344/INV9344-Investigacióndemercadosyanálisisdelacompetencia-10-4.xlsx. Tiempo: 0:00:00.009011
# Creado archivo CSV: Ruta Trabajo Final/Semestre 9/PRÁ9345/PRÁ9345-Prácticasprofesionales-20-1.csv. Tiempo: 0:00:00.001031
# Creado archivo Excel: Ruta Trabajo Final/Semestre 9/PRÁ9345/PRÁ9345-Prácticasprofesionales-20-1.xlsx. Tiempo: 0:00:00.011129
# Creado archivo CSV: Ruta Trabajo Final/Semestre 9/PRÁ9345/PRÁ9345-Prácticasprofesionales-20-2.csv. Tiempo: 0:00:00.001192
# Creado archivo Excel: Ruta Trabajo Final/Semestre 9/PRÁ9345/PRÁ9345-Prácticasprofesionales-20-2.xlsx. Tiempo: 0:00:00.012843
# Creado archivo CSV: Ruta Trabajo Final/Semestre 9/PRÁ9345/PRÁ9345-Prácticasprofesionales-20-3.csv. Tiempo: 0:00:00.001593
# Creado archivo Excel: Ruta Trabajo Final/Semestre 9/PRÁ9345/PRÁ9345-Prácticasprofesionales-20-3.xlsx. Tiempo: 0:00:00.009829
# Creado archivo CSV: Ruta Trabajo Final/Semestre 9/PRÁ9345/PRÁ9345-Prácticasprofesionales-10-4.csv. Tiempo: 0:00:00.001607
# Creado archivo Excel: Ruta Trabajo Final/Semestre 9/PRÁ9345/PRÁ9345-Prácticasprofesionales-10-4.xlsx. Tiempo: 0:00:00.009853
# Fin de la creación de archivos de cursos. Tiempo total: 0:00:03.580139
# Total de archivos creados: 404
# Total de acciones realizadas: 808

# %%
# Función para buscar un estudiante y sus cursos
def buscar_estudiante(nombre_completo, students, courses):
    estudiante = next((est for est in students if est['Nombre Completo'] == nombre_completo), None)
    if estudiante is None:
        return f"Error: El estudiante {nombre_completo} no existe."

    semestre = estudiante['Semestre']
    cursos_matriculados = [info['Nombre'] for code, info in courses.items() if semestre in info['Semestres']]
    cursos_str = "\n".join(cursos_matriculados)
    return f"Estudiante: {nombre_completo}\nSemestre: {semestre}\nCursos matriculados:\n{cursos_str}"

# Pedir al usuario el nombre del estudiante
nombre_estudiante = input("Ingrese el nombre completo del estudiante: ")
resultado = buscar_estudiante(nombre_estudiante, students, courses)
print(resultado)
# Out:
# Ingrese el nombre completo del estudiante:  Lucas  Moreno
# Estudiante:  Lucas  Moreno
# Semestre: 1
# Cursos matriculados:
# INGLÉS I
# INTRODUCCIÓN A LA INGENIERÍA INDUSTRIAL
# ÁLGEBRA Y TRIGONOMETRÍA
# GEOMETRÍA VECTORIAL Y ANALÍTICA
# CÁLCULO DIFERENCIAL
# LECTOESCRITURA
# VIVAMOS LA UNIVERSIDAD

# %%
import pandas as pd
import random
import os
import datetime
import logging
import platform

# Crear el directorio de logs si no existe
if not os.path.exists('logs'):
    os.makedirs('logs')

# Configuración del logger
log_file_path = os.path.join('logs', 'log.txt')
logging.basicConfig(filename=log_file_path, level=logging.INFO, format='%(asctime)s\t%(message)s')

# Función para registrar eventos con información adicional
def log_event(message):
    logging.info(message)

# Encabezado del log con información del sistema y usuario
system_info = platform.uname()
log_event(f"Sistema: {system_info.system}")
log_event(f"Nodo: {system_info.node}")
log_event(f"Release: {system_info.release}")
log_event(f"Versión: {system_info.version}")
log_event(f"Máquina: {system_info.machine}")
log_event(f"Procesador: {system_info.processor}")
log_event(f"_____________________________________________________________________________________")

# Función para leer nombres y apellidos de los archivos proporcionados
def read_names(file):
    return pd.read_csv(file, header=None, skiprows=1, encoding='utf-8').squeeze().tolist()

# Generación de datos únicos para los estudiantes
def generate_students(num_students, first_names, last_names):
    students = []
    unique_names = set()
    while len(students) < num_students:
        full_name = f"{random.choice(first_names)} {random.choice(last_names)}"
        if full_name not in unique_names:
            unique_names.add(full_name)
            students.append({'Nombre Completo': full_name})
    return students

# Distribución de estudiantes entre los semestres
def distribute_students(students):
    distribution = [0.14, 0.13, 0.12, 0.11, 0.10, 0.10, 0.09, 0.08, 0.07, 0.06]
    semester_counts = [int(len(students) * p) for p in distribution]
    semesters = []
    for i, count in enumerate(semester_counts):
        semesters.extend([i + 1] * count)
    random.shuffle(semesters)
    for student, semester in zip(students, semesters):
        student['Semestre'] = semester
    return students

# Función para obtener las iniciales del curso
def obtener_iniciales(nombre):
    palabras_comunes = {"DE", "LA", "DEL", "Y", "EL", "LOS", "LAS"}
    palabras = nombre.split()
    iniciales = [palabra[:3] for palabra in palabras if palabra.upper() not in palabras_comunes]
    return "".join(iniciales).upper()[:3]

# Función para calcular HTD y HTI basadas en los créditos
def calcular_horas(creditos):
    if creditos == 4:
        return 96, 120
    if creditos == 3:
        return 64, 80
    if creditos == 2:
        return 32, 64
    if creditos == 1:
        return 16, 32
    return 0, 0

# Generar el código único para cada materia
def generar_codigo(nombre, nivel, creditos, consecutivo):
    iniciales = obtener_iniciales(nombre)
    return f"{iniciales}{nivel}{creditos}{consecutivo}"

# Crear archivos de cursos
def create_course_files(students, courses, folder_path):
    start_time = datetime.datetime.now()
    log_event("Inicio de la creación de archivos de cursos")

    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
    grouped = {course: [] for course in courses}

    for student in students:
        for course, info in courses.items():
            if student['Semestre'] in info['Semestres']:
                grouped[course].append(student)

    for course, data in grouped.items():
        course_path = os.path.join(folder_path, f"Semestre {courses[course]['Semestres'][0]}", course)
        if not os.path.exists(course_path):
            os.makedirs(course_path)
        num_groups = len(data) // courses[course]['Cupo'] + (1 if len(data) % courses[course]['Cupo'] else 0)
        for i in range(num_groups):
            group_data = data[i * courses[course]['Cupo']:(i + 1) * courses[course]['Cupo']]
            if group_data:
                df = pd.DataFrame(group_data)[['Nombre Completo']]
                code = course
                course_name = courses[course]['Nombre'].replace(" ", "").capitalize()
                student_count = len(group_data)
                group_code = i + 1
                filename = f"{code}-{course_name}-{student_count}-{group_code}"
                filepath_csv = os.path.join(course_path, f"{filename}.csv")
                filepath_excel = os.path.join(course_path, f"{filename}.xlsx")
              # Crear archivo CSV
                csv_start_time = datetime.datetime.now()
                df.to_csv(filepath_csv, index=False, encoding='utf-8-sig')
                csv_end_time = datetime.datetime.now()
                csv_time_taken = csv_end_time - csv_start_time
                log_event(f'Creado archivo CSV: {filepath_csv}. Tiempo: {csv_time_taken}')

                # Crear archivo Excel
                excel_start_time = datetime.datetime.now()
                df.to_excel(filepath_excel, index=False)
                excel_end_time = datetime.datetime.now()
                excel_time_taken = excel_end_time - excel_start_time
                log_event(f'Creado archivo Excel: {filepath_excel}. Tiempo: {excel_time_taken}')

    end_time = datetime.datetime.now()
    total_time_taken = end_time - start_time
    log_event(f"Fin de la creación de archivos de cursos. Tiempo total: {total_time_taken}")


# Lista de materias con información
materias = [
    {"nivel": 1, "nombre": "INGLÉS I", "creditos": 1},
    {"nivel": 1, "nombre": "INTRODUCCIÓN A LA INGENIERÍA INDUSTRIAL", "creditos": 1},
    {"nivel": 1, "nombre": "ÁLGEBRA Y TRIGONOMETRÍA", "creditos": 3},
    {"nivel": 1, "nombre": "GEOMETRÍA VECTORIAL Y ANALÍTICA", "creditos": 3},
    {"nivel": 1, "nombre": "CÁLCULO DIFERENCIAL", "creditos": 3},
    {"nivel": 1, "nombre": "LECTOESCRITURA", "creditos": 3},
    {"nivel": 1, "nombre": "VIVAMOS LA UNIVERSIDAD", "creditos": 1},
    {"nivel": 2, "nombre": "INGLÉS II", "creditos": 1},
    {"nivel": 2, "nombre": "GESTIÓN DE LAS ORGANIZACIONES", "creditos": 3},
    {"nivel": 2, "nombre": "HABILIDADES GERENCIALES", "creditos": 3},
    {"nivel": 2, "nombre": "ÁLGEBRA LINEAL", "creditos": 3},
    {"nivel": 2, "nombre": "CÁLCULO INTEGRAL", "creditos": 3},
    {"nivel": 2, "nombre": "DESCUBRIENDO LA FÍSICA", "creditos": 3},
    {"nivel": 3, "nombre": "INGLÉS III", "creditos": 1},
    {"nivel": 3, "nombre": "GESTIÓN CONTABLE", "creditos": 3},
    {"nivel": 3, "nombre": "TEORÍA GENERAL DE SISTEMAS", "creditos": 3},
    {"nivel": 3, "nombre": "PROBABILIDAD E INFERENCIA ESTADÍSTICA", "creditos": 3},
    {"nivel": 3, "nombre": "ALGORITMIA Y PROGRAMACIÓN", "creditos": 3},
    {"nivel": 3, "nombre": "FÍSICA MECÁNICA", "creditos": 3},
    {"nivel": 4, "nombre": "INGLÉS IV", "creditos": 1},
    {"nivel": 4, "nombre": "GESTIÓN DE MÉTODOS Y TIEMPOS", "creditos": 4},
    {"nivel": 4, "nombre": "INGENIERÍA ECONÓMICA", "creditos": 3},
    {"nivel": 4, "nombre": "DISEÑO DE EXPERIMENTOS Y ANÁLISIS DE REGRESIÓN", "creditos": 3},
    {"nivel": 4, "nombre": "OPTIMIZACIÓN", "creditos": 3},
    {"nivel": 5, "nombre": "INGLÉS V", "creditos": 1},
    {"nivel": 5, "nombre": "DINÁMICA DE SISTEMAS", "creditos": 3},
    {"nivel": 5, "nombre": "GESTIÓN POR PROCESOS", "creditos": 3},
    {"nivel": 5, "nombre": "GESTIÓN FINANCIERA", "creditos": 3},
    {"nivel": 5, "nombre": "MUESTREO Y SERIES DE TIEMPO", "creditos": 3},
    {"nivel": 5, "nombre": "PROCESOS ESTOCÁSTICOS Y ANÁLISIS DE DECISIÓN", "creditos": 3},
    {"nivel": 6, "nombre": "INGLÉS VI", "creditos": 1},
    {"nivel": 6, "nombre": "GESTIÓN TECNOLÓGICA", "creditos": 3},
    {"nivel": 6, "nombre": "NORMALIZACIÓN Y CONTROL DE CALIDAD", "creditos": 3},
    {"nivel": 6, "nombre": "SIMULACIÓN", "creditos": 3},
    {"nivel": 6, "nombre": "SEGURIDAD Y SALUD EN EL TRABAJO", "creditos": 3},
    {"nivel": 7, "nombre": "GESTIÓN AMBIENTAL", "creditos": 3},
    {"nivel": 7, "nombre": "FORMULACIÓN Y EVALUACIÓN DE PROYECTOS", "creditos": 3},
    {"nivel": 7, "nombre": "GESTIÓN LOGÍSTICA Y DE LA CADENA DE SUMINISTRO", "creditos": 3},
    {"nivel": 7, "nombre": "MODELACIÓN DE SISTEMAS Y SIMULACIÓN DE PROCESOS", "creditos": 3},
    {"nivel": 8, "nombre": "GESTIÓN DEL TALENTO HUMANO", "creditos": 3},
    {"nivel": 8, "nombre": "GESTIÓN DE SERVICIOS", "creditos": 3},
    {"nivel": 8, "nombre": "PLANIFICACIÓN Y CONTROL DE LA PRODUCCIÓN", "creditos": 3},
    {"nivel": 8, "nombre": "PLANEACIÓN ESTRATÉGICA", "creditos": 3},
    {"nivel": 9, "nombre": "INVESTIGACIÓN DE MERCADOS Y ANÁLISIS DE LA COMPETENCIA", "creditos": 3},
    {"nivel": 9, "nombre": "PRÁCTICAS PROFESIONALES", "creditos": 3},
]

# Cursos y su configuración
courses = {}
consecutivo = 1
for materia in materias:
    codigo = generar_codigo(materia['nombre'], materia['nivel'], materia['creditos'], consecutivo)
    courses[codigo] = {
        'Semestres': [materia['nivel']],
        'Cupo': 30 if materia['nivel'] < 4 else 25 if materia['nivel'] < 7 else 20,
        'HTD': calcular_horas(materia['creditos'])[0],
        'HTI': calcular_horas(materia['creditos'])[1],
        'Nombre': materia['nombre']
    }
    consecutivo += 1

# Archivos de nombres y apellidos
first_names = read_names('nombres.csv')
last_names = read_names('apellidos.csv')

# Generar y distribuir estudiantes
students = generate_students(1000, first_names, last_names)
students = distribute_students(students)

# Crear archivos de cursos
create_course_files(students, courses, 'Ruta Trabajo Final')

# Finalizar el log de eventos con un resumen
total_files = sum([len(files) for r, d, files in os.walk('Ruta Trabajo Final')])
log_event(f"Total de archivos creados: {total_files}")
log_event(f"Total de acciones realizadas: {total_files * 2}")  # Cada archivo implica crear CSV y Excel, así que se multiplica por 2
